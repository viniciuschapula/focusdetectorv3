# %%
from ultralytics import YOLO

model = YOLO("bestV2.pt")

pathSave = "imagensReais\\resultado.mp4"
source = "C:\\focusdetectorv3\\ImagensReais\\VasoDeFlor01.mp4"

results = model(source)

for i, r in enumerate(results):
    r.save(pathSave)
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/242) C:\focusdetectorv3\ImagensReais\VasoDeFlor01.mp4: 640x384 (no detections), 525.0ms
# video 1/1 (frame 2/242) C:\focusdetectorv3\ImagensReais\VasoDeFlor01.mp4: 640x384 (no detections), 513.0ms
# video 1/1 (frame 3/242) C:\focusdetectorv3\ImagensReais\VasoDeFlor01.mp4: 640x384 (no detections), 512.0ms
# video 1/1 (frame 4/242) C:\focusdetectorv3\ImagensReais\VasoDeFlor01.mp4: 640x384 (no detections), 514.0ms
# ...
